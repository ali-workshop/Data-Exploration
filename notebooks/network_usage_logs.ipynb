# %%
# Imports libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
import bson

# %%
# Load multiple BSON objects from a file
def load_multiple_bson_objects(file_path):
    data = []
    with open(file_path, 'rb') as file:
        for document in bson.decode_all(file.read()):
            data.append(document)
    return data

# %%
network_usage_logs=r"D:\mongofiles\data\mydatabase\network_usage_logs.bson"

# %%
network_usage_data= load_multiple_bson_objects(network_usage_logs)

# %%
network_usage_data=pd.DataFrame(network_usage_data)

# %%
network_usage_data.head()
# Out:
#                         _id                   user_id username  \
# 0  665053963d97c3911fb3f036  66327fdb321870545078d205    user2
# 1  665053eae3be87291c85cd7a  66403324c6d3b6e77f917976    user1
# 2  66505426e3be87291c85cd7c  66403324c6d3b6e77f917976    user1
# 3  6650557ef5bebd88f01ed21b  66322d94f89c7cd14b365ea8    mahad
# 4  665057e7b4bee6cd9cb5320f  66322d94f89c7cd14b365ea8    mahad
#
#                 timestamp  bytes_sent  bytes_recv  packets_sent  packets_recv  \
# 0 2024-05-24 12:45:10.477    40612106   360611960        127164        878909
# 1 2024-05-24 12:46:34.692    41305634   363551102        129835        897377
# 2 2024-05-24 12:47:34.891    41516330   365038815        130940        909242
# 3 2024-05-24 12:53:18.344    44254058   399045518        142220        988754
# 4 2024-05-24 13:03:35.432    96987861   541238403        168122       1190498
#
#    errin  errout  dropin  dropout  total_connections  \
# 0      0       0       0        0               2242
# 1      0       0       0        0               2009
# 2      0       0       0        0               1777
# 3      0       0       0        0               2192
# 4      0       0       0        0               2176
#
#                                        status_counts  \
# 0  {'LISTEN': 30, 'TIME_WAIT': 2008, 'NONE': 53, ...
# 1  {'TIME_WAIT': 1780, 'NONE': 49, 'ESTABLISHED':...
# 2  {'TIME_WAIT': 1544, 'NONE': 52, 'ESTABLISHED':...
# 3  {'TIME_WAIT': 1980, 'ESTABLISHED': 131, 'NONE'...
# 4  {'TIME_WAIT': 1959, 'ESTABLISHED': 135, 'NONE'...
#
#                                          type_counts
# 0  {'SocketKind.SOCK_STREAM': 2189, 'SocketKind.S...
# 1  {'SocketKind.SOCK_STREAM': 1960, 'SocketKind.S...
# 2  {'SocketKind.SOCK_STREAM': 1725, 'SocketKind.S...
# 3  {'SocketKind.SOCK_STREAM': 2142, 'SocketKind.S...
# 4  {'SocketKind.SOCK_STREAM': 2126, 'SocketKind.S...

# %%
network_usage_data.columns
# Out:
# Index(['_id', 'user_id', 'username', 'timestamp', 'bytes_sent', 'bytes_recv',
#        'packets_sent', 'packets_recv', 'errin', 'errout', 'dropin', 'dropout',
#        'total_connections', 'status_counts', 'type_counts'],
#       dtype='object')

# %%
network_usage_data.dtypes
# Out:
# _id                          object
# user_id                      object
# username                     object
# timestamp            datetime64[ns]
# bytes_sent                    int64
# bytes_recv                    int64
# packets_sent                  int64
# packets_recv                  int64
# errin                         int64
# errout                        int64
# dropin                        int64
# dropout                       int64
# total_connections             int64
# status_counts                object
# type_counts                  object
# dtype: object

# %%
network_usage_data['type_counts'][0]
# Out:
# {'SocketKind.SOCK_STREAM': 2189, 'SocketKind.SOCK_DGRAM': 53}

# %%
network_usage_data['status_counts'][0]
# Out:
# {'LISTEN': 30,
#  'TIME_WAIT': 2008,
#  'NONE': 53,
#  'ESTABLISHED': 149,
#  'CLOSE_WAIT': 2}

# %%
# Split dictionary values some columns.
def split_dict_column(df, column_name):
    dict_df = df[column_name].apply(pd.Series)
    df = df.drop(column_name, axis=1).join(dict_df)
    return df

# %%
network_usage_data = split_dict_column(network_usage_data, 'type_counts')

# %%
network_usage_data = split_dict_column(network_usage_data, 'status_counts')

# %%
network_usage_data.head()
# Out:
#                         _id                   user_id username  \
# 0  665053963d97c3911fb3f036  66327fdb321870545078d205    user2
# 1  665053eae3be87291c85cd7a  66403324c6d3b6e77f917976    user1
# 2  66505426e3be87291c85cd7c  66403324c6d3b6e77f917976    user1
# 3  6650557ef5bebd88f01ed21b  66322d94f89c7cd14b365ea8    mahad
# 4  665057e7b4bee6cd9cb5320f  66322d94f89c7cd14b365ea8    mahad
#
#                 timestamp  bytes_sent  bytes_recv  packets_sent  packets_recv  \
# 0 2024-05-24 12:45:10.477    40612106   360611960        127164        878909
# 1 2024-05-24 12:46:34.692    41305634   363551102        129835        897377
# 2 2024-05-24 12:47:34.891    41516330   365038815        130940        909242
# 3 2024-05-24 12:53:18.344    44254058   399045518        142220        988754
# 4 2024-05-24 13:03:35.432    96987861   541238403        168122       1190498
#
#    errin  errout  ...  total_connections  SocketKind.SOCK_STREAM  \
# 0      0       0  ...               2242                    2189
# 1      0       0  ...               2009                    1960
# 2      0       0  ...               1777                    1725
# 3      0       0  ...               2192                    2142
# 4      0       0  ...               2176                    2126
#
#    SocketKind.SOCK_DGRAM  LISTEN  TIME_WAIT  NONE  ESTABLISHED  CLOSE_WAIT  \
# 0                     53    30.0     2008.0  53.0        149.0         2.0
# 1                     49    30.0     1780.0  49.0        148.0         1.0
# 2                     52    30.0     1544.0  52.0        150.0         NaN
# 3                     50    30.0     1980.0  50.0        131.0         1.0
# 4                     50    30.0     1959.0  50.0        135.0         1.0
#
#    SYN_SENT  LAST_ACK
# 0       NaN       NaN
# 1       1.0       NaN
# 2       NaN       1.0
# 3       NaN       NaN
# 4       1.0       NaN
#
# [5 rows x 22 columns]

# %%
network_usage_data.columns
# Out:
# Index(['_id', 'user_id', 'username', 'timestamp', 'bytes_sent', 'bytes_recv',
#        'packets_sent', 'packets_recv', 'errin', 'errout', 'dropin', 'dropout',
#        'total_connections', 'SocketKind.SOCK_STREAM', 'SocketKind.SOCK_DGRAM',
#        'LISTEN', 'TIME_WAIT', 'NONE', 'ESTABLISHED', 'CLOSE_WAIT', 'SYN_SENT',
#        'LAST_ACK'],
#       dtype='object')

# %%
network_usage_data.drop(columns=['_id','user_id'],inplace=True)

# %%
network_usage_data.columns
# Out:
# Index(['username', 'timestamp', 'bytes_sent', 'bytes_recv', 'packets_sent',
#        'packets_recv', 'errin', 'errout', 'dropin', 'dropout',
#        'total_connections', 'SocketKind.SOCK_STREAM', 'SocketKind.SOCK_DGRAM',
#        'LISTEN', 'TIME_WAIT', 'NONE', 'ESTABLISHED', 'CLOSE_WAIT', 'SYN_SENT',
#        'LAST_ACK'],
#       dtype='object')

# %%
network_usage_data.set_index('timestamp',inplace=True)

# %%
network_usage_data.columns
# Out:
# Index(['username', 'bytes_sent', 'bytes_recv', 'packets_sent', 'packets_recv',
#        'errin', 'errout', 'dropin', 'dropout', 'total_connections',
#        'SocketKind.SOCK_STREAM', 'SocketKind.SOCK_DGRAM', 'LISTEN',
#        'TIME_WAIT', 'NONE', 'ESTABLISHED', 'CLOSE_WAIT', 'SYN_SENT',
#        'LAST_ACK'],
#       dtype='object')

# %%
network_usage_data.head()
# Out:
#                         username  bytes_sent  bytes_recv  packets_sent  \
# timestamp
# 2024-05-24 12:45:10.477    user2    40612106   360611960        127164
# 2024-05-24 12:46:34.692    user1    41305634   363551102        129835
# 2024-05-24 12:47:34.891    user1    41516330   365038815        130940
# 2024-05-24 12:53:18.344    mahad    44254058   399045518        142220
# 2024-05-24 13:03:35.432    mahad    96987861   541238403        168122
#
#                          packets_recv  errin  errout  dropin  dropout  \
# timestamp
# 2024-05-24 12:45:10.477        878909      0       0       0        0
# 2024-05-24 12:46:34.692        897377      0       0       0        0
# 2024-05-24 12:47:34.891        909242      0       0       0        0
# 2024-05-24 12:53:18.344        988754      0       0       0        0
# 2024-05-24 13:03:35.432       1190498      0       0       0        0
#
#                          total_connections  SocketKind.SOCK_STREAM  \
# timestamp
# 2024-05-24 12:45:10.477               2242                    2189
# 2024-05-24 12:46:34.692               2009                    1960
# 2024-05-24 12:47:34.891               1777                    1725
# 2024-05-24 12:53:18.344               2192                    2142
# 2024-05-24 13:03:35.432               2176                    2126
#
#                          SocketKind.SOCK_DGRAM  LISTEN  TIME_WAIT  NONE  \
# timestamp
# 2024-05-24 12:45:10.477                     53    30.0     2008.0  53.0
# 2024-05-24 12:46:34.692                     49    30.0     1780.0  49.0
# 2024-05-24 12:47:34.891                     52    30.0     1544.0  52.0
# 2024-05-24 12:53:18.344                     50    30.0     1980.0  50.0
# 2024-05-24 13:03:35.432                     50    30.0     1959.0  50.0
#
#                          ESTABLISHED  CLOSE_WAIT  SYN_SENT  LAST_ACK
# timestamp
# 2024-05-24 12:45:10.477        149.0         2.0       NaN       NaN
# 2024-05-24 12:46:34.692        148.0         1.0       1.0       NaN
# 2024-05-24 12:47:34.891        150.0         NaN       NaN       1.0
# 2024-05-24 12:53:18.344        131.0         1.0       NaN       NaN
# 2024-05-24 13:03:35.432        135.0         1.0       1.0       NaN

# %%
#Next
# Apply Processing steps
